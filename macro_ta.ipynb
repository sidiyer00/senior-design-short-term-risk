# %%
import pandas as pd
import numpy as np
import plotly.express as px

import ta
import pandas_datareader as pdr

# %%
macro_data = pd.read_csv("data_gathering (2).csv", index_col="date")
macro_data = macro_data.interpolate()

# %%
prices = pdr.get_data_yahoo(["^GSPC", "VXX"], start = "2019-01-01", end = "2021-11-10")["Close"]
